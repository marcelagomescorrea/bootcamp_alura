# %% [markdown]
# Caderno de exploração dos dados do datasus 2008 pra frente

# %%
url='https://raw.githubusercontent.com/alura-cursos/agendamento-hospitalar/main/dados/A151346189_28_143_208.csv'

# %%
url2='https://raw.githubusercontent.com/alura-cursos/agendamento-hospitalar/main/dados/A160324189_28_143_208.csv'

# %%
import pandas as pd

# %%
dados = pd.read_csv(url, encoding="ISO-8859-1", 
                    skiprows = 3, sep=";", skipfooter=12,
                    thousands=".", decimal=",")
dados.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: ParserWarning:
#
# Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   Unidade da Federação    2008/Jan  ...     2020/Ago         Total
# 0          11 Rondônia  1388528.39  ...  10285455.78  929129659.72
# 1              12 Acre   902416.00  ...            -  420668039.63
# 2          13 Amazonas  4735529.42  ...  14726443.67 1771654871.23
# 3           14 Roraima   657889.53  ...   2826486.18  305010883.18
# 4              15 Pará 18864744.11  ...  39911193.02 4437115730.71
#
# [5 rows x 154 columns]

# %%
dados.tail()
# Out:
#      Unidade da Federação    2008/Jan  ...      2020/Ago          Total
# 22   43 Rio Grande do Sul 30931325.46  ...  101374341.51 11958647088.33
# 23  50 Mato Grosso do Sul  5377392.11  ...   19241624.02  2172157981.36
# 24         51 Mato Grosso  4795299.01  ...   17790649.87  2036923784.59
# 25               52 Goiás 15310637.29  ...   43984702.05  4657350310.70
# 26    53 Distrito Federal  4745919.19  ...   26526196.39  2429933198.76
#
# [5 rows x 154 columns]

# %%
dados.mean()
# Out:
# 2008/Jan     15126846.64
# 2008/Fev     22710158.12
# 2008/Mar     24594187.35
# 2008/Abr     25431957.83
# 2008/Mai     26511245.91
#                 ...
# 2020/Abr     41013660.39
# 2020/Mai     44193633.75
# 2020/Jun     47329994.46
# 2020/Jul     54495511.57
# Total      5993731798.30
# Length: 151, dtype: float64

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
dados.mean()
# Out:
# 2008/Jan     15126846.64
# 2008/Fev     22710158.12
# 2008/Mar     24594187.35
# 2008/Abr     25431957.83
# 2008/Mai     26511245.91
#                 ...
# 2020/Abr     41013660.39
# 2020/Mai     44193633.75
# 2020/Jun     47329994.46
# 2020/Jul     54495511.57
# Total      5993731798.30
# Length: 151, dtype: float64

# %%
dados['2008/Ago'].mean()
# Out:
# 27800320.306666665

# %%
dados.plot(x='Unidade da Federação', y='2008/Ago',kind='bar',figsize=(16,4))

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
periodo_filtrado = '2020/Jul'

ax= dados.plot(x='Unidade da Federação', y=periodo_filtrado,kind='bar',figsize=(16,4))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
plt.title("Valores totais gastos em " + periodo_filtrado + " com procedimentos hospitalares por unidade da federação")
# Out:
# Text(0.5, 1.0, 'Valores totais gastos em 2020/Jul com procedimentos hospitalares por unidade da federação')

# %%
periodo_filtrado = '2018/Ago'

ax= dados.plot(x='Unidade da Federação', y=periodo_filtrado,kind='bar',figsize=(16,4))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
plt.title("Valores totais gastos em " + periodo_filtrado + " com procedimentos hospitalares por unidade da federação")
# Out:
# Text(0.5, 1.0, 'Valores totais gastos em 2018/Ago com procedimentos hospitalares por unidade da federação')

# %%
dados = pd.read_csv(url2, encoding="ISO-8859-1", 
                    skiprows = 3, sep=";", skipfooter=12,
                    thousands=".", decimal=",")
dados.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: ParserWarning:
#
# Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   Unidade da Federação 1992/Mar 1992/Abr  ...    2020/Jul     2020/Ago         Total
# 0          11 Rondônia        -        -  ...  7407388.24   3556381.57  929129659.72
# 1              12 Acre        -        -  ...  1163813.08            -  420668039.63
# 2          13 Amazonas        -        -  ... 13358514.02   4726485.73 1771654871.23
# 3           14 Roraima        -        -  ...  2739498.41   1524478.04  305010883.18
# 4              15 Pará        -        -  ... 27618727.51  11559714.54 4437115730.71
#
# [5 rows x 280 columns]

# %%
dados[['2008/Ago','2008/Set']].head()
# Out:
#      2008/Ago    2008/Set
# 0  2938286.29  2843930.91
# 1  1886871.84  2084884.80
# 2  8331763.97  8148089.92
# 3  1045291.11  1003740.89
# 4 23259148.28 23667690.01

# %%
colunas_usaveis = dados.mean().index.tolist()
colunas_usaveis.insert(0,'Unidade da Federação')
colunas_usaveis
# Out:
# ['Unidade da Federação',
#  '2007/Ago',
#  '2007/Set',
#  '2007/Out',
#  '2007/Nov',
#  '2007/Dez',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
# ...

# %%
usaveis = dados[colunas_usaveis]

# %%
usaveis = usaveis.set_index('Unidade da Federação')

# %%
usaveis.loc['12 Acre']
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2020/Abr     2472063.08
# 2020/Mai     2383895.48
# 2020/Jun     2199920.70
# 2020/Jul     1163813.08
# Total      420668039.63
# Name: 12 Acre, Length: 157, dtype: float64

# %%
usaveis.T.tail()
# Out:
# Unidade da Federação  11 Rondônia  ...  53 Distrito Federal
# 2020/Abr               7423678.64  ...          18123899.78
# 2020/Mai               8581195.13  ...          21437430.22
# 2020/Jun               9193593.76  ...          23479773.03
# 2020/Jul               7407388.24  ...          22233542.26
# Total                929129659.72  ...        2429933198.76
#
# [5 rows x 27 columns]

# %%
usaveis = usaveis.drop('Total',axis=1)

# %%
usaveis.T.plot(figsize=(10,6))
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")

# %%
df = px.data.gapminder().query("continent=='Oceania'")

# %%
df.head()
# Out:
#       country continent  year  lifeExp       pop  gdpPercap iso_alpha  iso_num
# 60  Australia   Oceania  1952    69.12   8691212   10039.60       AUS       36
# 61  Australia   Oceania  1957    70.33   9712569   10949.65       AUS       36
# 62  Australia   Oceania  1962    70.93  10794968   12217.23       AUS       36
# 63  Australia   Oceania  1967    71.10  11872264   14526.12       AUS       36
# 64  Australia   Oceania  1972    71.93  13177000   16788.63       AUS       36

# %%
cincoestados = usaveis.T[['11 Rondônia','12 Acre',	'13 Amazonas',	'14 Roraima',	'15 Pará']]

# %%
cincoestados
# Out:
# Unidade da Federação  11 Rondônia    12 Acre  ...  14 Roraima     15 Pará
# 2007/Ago                  4209.37   10470.07  ...     4785.91   181159.29
# 2007/Set                 16397.03   14001.71  ...    11858.63   433414.74
# 2007/Out                133645.19   86200.85  ...    43852.67  1893197.50
# 2007/Nov                346912.84  301323.68  ...   369328.51  5105406.44
# 2007/Dez                711758.31  769612.36  ...   470676.43 13162823.43
# ...                           ...        ...  ...         ...         ...
# 2020/Mar               7174312.31 2859102.06  ...  2813954.05 34749098.46
# 2020/Abr               7423678.64 2472063.08  ...  2304961.42 28714969.96
# 2020/Mai               8581195.13 2383895.48  ...  2910776.44 41248502.78
# 2020/Jun               9193593.76 2199920.70  ...  3216466.51 35396030.78
# 2020/Jul               7407388.24 1163813.08  ...  2739498.41 27618727.51
#
# [156 rows x 5 columns]

# %%
ax=cincoestados.plot(figsize=(10,6),colormap='tab20c')
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))

# %%
import numpy as np

# %%
df.head()
# Out:
#       country continent  year  lifeExp       pop  gdpPercap iso_alpha  iso_num
# 60  Australia   Oceania  1952    69.12   8691212   10039.60       AUS       36
# 61  Australia   Oceania  1957    70.33   9712569   10949.65       AUS       36
# 62  Australia   Oceania  1962    70.93  10794968   12217.23       AUS       36
# 63  Australia   Oceania  1967    71.10  11872264   14526.12       AUS       36
# 64  Australia   Oceania  1972    71.93  13177000   16788.63       AUS       36

# %%
cincoestados.columns
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
np.random.seed(687942)
usaveis.sample(7)
# Out:
#                         2007/Ago   2007/Set  ...     2020/Jun     2020/Jul
# Unidade da Federação                         ...
# 32 Espírito Santo       57408.11  284224.80  ...  27450865.16  27460475.47
# 31 Minas Gerais        971394.37 2861781.50  ... 135977571.87 120467187.34
# 24 Rio Grande do Norte 134605.36  272088.08  ...  20219961.81  19593057.45
# 17 Tocantins             4113.76   76633.06  ...   5018138.13   4489665.87
# 53 Distrito Federal    191951.47  769966.25  ...  23479773.03  22233542.26
# 50 Mato Grosso do Sul  199556.12  573675.41  ...  15838659.34  12508717.35
# 16 Amapá                33672.74  104822.98  ...   2699492.23   2155083.37
#
# [7 rows x 156 columns]

# %%
usaveis['Total'] = usaveis.sum(axis=1)
usaveis.head()
# Out:
#                       2007/Ago  2007/Set  ...    2020/Jul         Total
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ...  7407388.24  925572673.82
# 12 Acre               10470.07  14001.71  ...  1163813.08  420666755.81
# 13 Amazonas           35752.72  45570.64  ... 13358514.02 1766925554.09
# 14 Roraima             4785.91  11858.63  ...  2739498.41  303485991.45
# 15 Pará              181159.29 433414.74  ... 27618727.51 4425537480.57
#
# [5 rows x 157 columns]

# %%
ordenado_por_total = usaveis.sort_values("Total", ascending=False)
ordenado_por_total = ordenado_por_total.drop("Total", axis=1)
ordenado_por_total.head()
# Out:
#                        2007/Ago   2007/Set  ...     2020/Jun     2020/Jul
# Unidade da Federação                        ...
# 35 São Paulo         1665349.90 4434168.64  ... 299060851.62 282709570.31
# 31 Minas Gerais       971394.37 2861781.50  ... 135977571.87 120467187.34
# 41 Paraná             554800.22 1431708.01  ...  92901461.36  80320852.69
# 43 Rio Grande do Sul 1049252.33 3182913.14  ...  89019478.82  78929703.81
# 33 Rio de Janeiro     469469.34  921646.57  ...  77604925.21  71540227.33
#
# [5 rows x 156 columns]

# %%
ax=ordenado_por_total.head(5).T.plot(figsize=(10,6),colormap='Paired')
#plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))

# %%
colunas_interessadas = ordenado_por_total.columns[6:]
ordenado_por_total = ordenado_por_total[colunas_interessadas]

# %%
ordenado_por_total = ordenado_por_total/1000000

# %%
ordenado_por_total[ordenado_por_total.columns[47:150]].head(3).T.plot(figsize=(10,6))
plt.ylim(100, 350)
# Out:
# (100.0, 350.0)

# %%
ordenado_por_total[ordenado_por_total.columns[-12:]].head(3).T.plot(figsize=(10,6))
plt.ylim(0, 350)
# Out:
# (0.0, 350.0)

# %%
mes_mais_recente = ordenado_por_total.columns[-1]

# %%
gastos_do_ultimo_mes = ordenado_por_total[mes_mais_recente]
gastos_do_ultimo_mes
# Out:
# Unidade da Federação
# 35 São Paulo             282.71
# 31 Minas Gerais          120.47
# 41 Paraná                 80.32
# 43 Rio Grande do Sul      78.93
# 33 Rio de Janeiro         71.54
# 29 Bahia                  58.90
# 26 Pernambuco             62.33
# 42 Santa Catarina         51.76
# 23 Ceará                  30.81
# 52 Goiás                  33.50
# 15 Pará                   27.62
# 21 Maranhão               24.37
# 32 Espírito Santo         27.46
# 24 Rio Grande do Norte    19.59
# 25 Paraíba                15.49
# 53 Distrito Federal       22.23
# 50 Mato Grosso do Sul     12.51
# 22 Piauí                  18.02
# 27 Alagoas                13.09
# 51 Mato Grosso            13.08
# 13 Amazonas               13.36
# 28 Sergipe                 3.31
# 17 Tocantins               4.49
# 11 Rondônia                7.41
# 12 Acre                    1.16
# 14 Roraima                 2.74
# 16 Amapá                   2.16
# Name: 2020/Jul, dtype: float64

# %%
gastos_do_ultimo_mes.plot(kind='pie')

# %%
gastos_do_ultimo_mes / gastos_do_ultimo_mes.loc['33 Rio de Janeiro']
# Out:
# Unidade da Federação
# 35 São Paulo             3.95
# 31 Minas Gerais          1.68
# 41 Paraná                1.12
# 43 Rio Grande do Sul     1.10
# 33 Rio de Janeiro        1.00
# 29 Bahia                 0.82
# 26 Pernambuco            0.87
# 42 Santa Catarina        0.72
# 23 Ceará                 0.43
# 52 Goiás                 0.47
# 15 Pará                  0.39
# 21 Maranhão              0.34
# 32 Espírito Santo        0.38
# 24 Rio Grande do Norte   0.27
# 25 Paraíba               0.22
# 53 Distrito Federal      0.31
# 50 Mato Grosso do Sul    0.17
# 22 Piauí                 0.25
# 27 Alagoas               0.18
# 51 Mato Grosso           0.18
# 13 Amazonas              0.19
# 28 Sergipe               0.05
# 17 Tocantins             0.06
# 11 Rondônia              0.10
# 12 Acre                  0.02
# 14 Roraima               0.04
# 16 Amapá                 0.03
# Name: 2020/Jul, dtype: float64

# %%
gastos_do_ultimo_mes = gastos_do_ultimo_mes.sort_values(ascending=False)
gastos_do_ultimo_mes.plot(kind='bar')

# %%
import plotly.express as px

# %%
gastos_do_ultimo_mes.head()
# Out:
# Unidade da Federação
# 35 São Paulo           282.71
# 31 Minas Gerais        120.47
# 41 Paraná               80.32
# 43 Rio Grande do Sul    78.93
# 33 Rio de Janeiro       71.54
# Name: 2020/Jul, dtype: float64

# %%
gastos_do_ultimo_mes.index
# Out:
# Index(['35 São Paulo', '31 Minas Gerais', '41 Paraná', '43 Rio Grande do Sul',
#        '33 Rio de Janeiro', '26 Pernambuco', '29 Bahia', '42 Santa Catarina',
#        '52 Goiás', '23 Ceará', '15 Pará', '32 Espírito Santo', '21 Maranhão',
#        '53 Distrito Federal', '24 Rio Grande do Norte', '22 Piauí',
#        '25 Paraíba', '13 Amazonas', '27 Alagoas', '51 Mato Grosso',
#        '50 Mato Grosso do Sul', '11 Rondônia', '17 Tocantins', '28 Sergipe',
#        '14 Roraima', '16 Amapá', '12 Acre'],
#       dtype='object', name='Unidade da Federação')

# %%
fig2 = px.bar(x=gastos_do_ultimo_mes.index, 
              y=gastos_do_ultimo_mes,labels={'x':'Unidade da Federação','y':'Gastos'})

fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c2d3233f-79a6-4ff4-85c9-3a3d2ff84808" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c2d3233f-79a6-4ff4-85c9-3a3d2ff84808")) {
#                     Plotly.newPlot(
#                         'c2d3233f-79a6-4ff4-85c9-3a3d2ff84808',
# ...

# %%
fig2.write_html('imagem.html')

# %% [markdown]
# https://peixebabel.github.io/COVID-19/

# %%
ibge_estimativa = pd.read_excel('https://github.com/alura-cursos/agendamento-hospitalar/raw/main/dados/estimativa_dou_2020.xls')

# %%
dados_da_populacao = """

Posição	Unidade federativa	População	% da pop. total	País comparável
(habitantes)

1	 São Paulo	46 289 333	21,9%	Flag of Spain.svg Espanha (46 439 864)
2	 Minas Gerais	21 331 292	10,1%	 Sri Lanka (20 675 000)
3	 Rio de Janeiro	17 366 189	8,2%	 Países Baixos (16 922 900)
4	Bahia Bahia	14 930 634	7,1%	 Chade (14 037 000)
5	 Paraná	11 516 840	5,4%	 Bolívia (11 410 651)
6	 Rio Grande do Sul	11 422 973	5,4%	 Bélgica (11 250 659)
7	 Pernambuco	9 616 621	4,5%	 Bielorrússia (9 485 300)
8	 Ceará	9 187 103	4,3%	 Emirados Árabes Unidos (9 157 000)
9	Pará Pará	8 690 745	4,1%	 Áustria (8 602 112)
10	 Santa Catarina	7 279 638	3,4%	 Sérvia (7 114 393)
12	 Goiás	7 142 070	3,4%	 Paraguai (7 003 406)
11	 Maranhão	7 127 460	3,4%	 Paraguai (7 003 406)
13	 Amazonas	4 228 381	2,0%	 Líbano (4 168 000)
14	 Espírito Santo	4 064 052	1,9%	 Líbano (4 168 000)
15	 Paraíba	4 039 277	1,9%	 Líbano (4 168 000)
16	 Rio Grande do Norte	3 534 165	1,7%	 Uruguai (3 415 866)
17	 Mato Grosso	3 526 220	1,7%	 Uruguai (3 415 866)
18	 Alagoas	3 351 543	1,6%	 Uruguai (3 415 866)
19	 Piauí	3 281 480	1,6%	 Kuwait (3 268 431)
20	 Distrito Federal	3 055 149	1,4%	 Lituânia (2 900 787)
21	 Mato Grosso do Sul	2 809 394	1,3%	 Jamaica (2 717 991)
22	 Sergipe	2 318 822	1,1%	 Namíbia (2 280 700)
23	 Rondônia	1 796 460	0,8%	 Gabão (1 725 000)
24	 Tocantins	1 590 248	0,7%	 Bahrein (1 359 800)
25	 Acre	894 470	0,4%	 Fiji (859 178)
26	 Amapá	861 773	0,4%	 Fiji (859 178)
27	 Roraima	631 181	0,3%	 Luxemburgo (562 958)"""

# %%
from io import StringIO

dados_da_populacao_io = StringIO(dados_da_populacao)

populacao = pd.read_csv(dados_da_populacao_io,sep='\t')
populacao = populacao.dropna()
populacao['populacao'] = populacao['População'].str.replace(" ","").astype(int)
populacao['uf'] = populacao['Unidade federativa']

populacao = populacao[['populacao','uf']].set_index('uf')
display(populacao.head())
display(populacao.info())
# Out:
#                  populacao
# uf
#  São Paulo        46289333
#  Minas Gerais     21331292
#  Rio de Janeiro   17366189
# Bahia Bahia       14930634
#  Paraná           11516840
# <class 'pandas.core.frame.DataFrame'>
# Index: 27 entries,  São Paulo to  Roraima
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   populacao  27 non-null     int64
# dtypes: int64(1)
# memory usage: 432.0+ bytes
# None

# %%
gastos_do_ultimo_mes.head()
# Out:
# Unidade da Federação
# 35 São Paulo           282.71
# 31 Minas Gerais        120.47
# 41 Paraná               80.32
# 43 Rio Grande do Sul    78.93
# 33 Rio de Janeiro       71.54
# Name: 2020/Jul, dtype: float64

# %%
gastos_do_ultimo_mes.index = gastos_do_ultimo_mes.index.str[3:]

# %%
for estado in gastos_do_ultimo_mes.index:
  #print(f"{estado} {estado} => {estado}")
  populacao.index = populacao.index.str.replace(f"{estado} {estado}", estado)

populacao.index
# Out:
# Index([' São Paulo', ' Minas Gerais', ' Rio de Janeiro', 'Bahia', ' Paraná',
#        ' Rio Grande do Sul', ' Pernambuco', ' Ceará', 'Pará',
#        ' Santa Catarina', ' Goiás', ' Maranhão', ' Amazonas',
#        ' Espírito Santo', ' Paraíba', ' Rio Grande do Norte', ' Mato Grosso',
#        ' Alagoas', ' Piauí', ' Distrito Federal', ' Mato Grosso do Sul',
#        ' Sergipe', ' Rondônia', ' Tocantins', ' Acre', ' Amapá', ' Roraima'],
#       dtype='object', name='uf')

# %%
#populacao.index[0] = populacao.index[0].str[1:]

# %%
populacao.index
# Out:
# Index([' São Paulo', ' Minas Gerais', ' Rio de Janeiro', 'Bahia', ' Paraná',
#        ' Rio Grande do Sul', ' Pernambuco', ' Ceará', 'Pará',
#        ' Santa Catarina', ' Goiás', ' Maranhão', ' Amazonas',
#        ' Espírito Santo', ' Paraíba', ' Rio Grande do Norte', ' Mato Grosso',
#        ' Alagoas', ' Piauí', ' Distrito Federal', ' Mato Grosso do Sul',
#        ' Sergipe', ' Rondônia', ' Tocantins', ' Acre', ' Amapá', ' Roraima'],
#       dtype='object', name='uf')

# %%
populacao.index = populacao.index.str.strip()

# %%
populacao.join(gastos_do_ultimo_mes)
# Out:
#                      populacao  2020/Jul
# uf
# São Paulo             46289333    282.71
# Minas Gerais          21331292    120.47
# Rio de Janeiro        17366189     71.54
# Bahia                 14930634     58.90
# Paraná                11516840     80.32
# Rio Grande do Sul     11422973     78.93
# Pernambuco             9616621     62.33
# Ceará                  9187103     30.81
# Pará                   8690745     27.62
# Santa Catarina         7279638     51.76
# Goiás                  7142070     33.50
# Maranhão               7127460     24.37
# Amazonas               4228381     13.36
# Espírito Santo         4064052     27.46
# Paraíba                4039277     15.49
# Rio Grande do Norte    3534165     19.59
# Mato Grosso            3526220     13.08
# Alagoas                3351543     13.09
# Piauí                  3281480     18.02
# Distrito Federal       3055149     22.23
# Mato Grosso do Sul     2809394     12.51
# Sergipe                2318822      3.31
# ...

# %%
ax=cincoestados.plot(figsize=(10,6),colormap='tab20c')
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))

# %%
import plotly.graph_objects as go

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(x=cincoestados.index, y=cincoestados['11 Rondônia'],name='Rondônia'))
fig.add_trace(go.Scatter(x=cincoestados.index, y=cincoestados['12 Acre'],name='Acre'))
fig.add_trace(go.Scatter(x=cincoestados.index, y=cincoestados['13 Amazonas'],name='Amazonas'))
fig.add_trace(go.Scatter(x=cincoestados.index, y=cincoestados['14 Roraima'],name='Roraima'))
fig.add_trace(go.Scatter(x=cincoestados.index, y=cincoestados['15 Pará'],name='Pará'))

fig.show()

# %%
gastos_do_ultimo_mes = gastos_do_ultimo_mes.sort_values(ascending=False)
gastos_do_ultimo_mes.plot(kind='bar')

# %%
import plotly.express as px

# %%
fig2 = px.bar(x=gastos_do_ultimo_mes.index, 
              y=gastos_do_ultimo_mes,labels={'x':'Unidade da Federação','y':'Gastos'})

fig2.show()

# %%
fig2.write_html('imagem.html')
